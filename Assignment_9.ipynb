# %% [markdown]
# <a href="https://colab.research.google.com/github/171473/Advanced-Software-System-Lab/blob/master/Assignment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ans1.Uploading a csv file from a local folder into colab

# %%
from google.colab import files 
up = files.upload()
uploaded = files.upload()
import pandas as pd 
import io 
df = pd.read_csv(io.BytesIO(up['iris.csv']))
dff = pd.read_csv(io.BytesIO(uploaded['wine.csv']))  
print(df)
print(dff)
# Out:
#      <input type="file" id="files-2114df73-7e8c-4a0b-9d45-9a7405858036" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2114df73-7e8c-4a0b-9d45-9a7405858036">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris (1).csv
#      <input type="file" id="files-63b03940-ae33-4fd9-b645-f276486afef3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63b03940-ae33-4fd9-b645-f276486afef3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wine.csv to wine (1).csv
# ...

# %% [markdown]
# ANS2.Uploading csv file from github

# %%
import pandas as pd
import matplotlib.pyplot as plt
url1 = 'https://gist.github.com/curran/a08a1080b88344b0c8a7/raw/639388c2cbc2120a14dcf466e85730eb8be498bb/iris.csv'
df2 = pd.read_csv(url1)

setosa=df2[df2['species']=='setosa']
versicolor =df2[df2['species']=='versicolor']
virginica =df2[df2['species']=='virginica']

print(setosa.describe())
print(versicolor.describe())
print(virginica.describe())

print(df2.describe())


plt.figure()
fig,ax=plt.subplots(1,2,figsize=(17, 9))
print(ax[0])
df2.plot(x='sepal_length', y='sepal_width', kind='scatter',ax=ax[0],sharex=False,sharey=False,label="sepal",color='r')
df2.plot(x="petal_length",y="petal_width",kind="scatter",ax=ax[1],sharex=False,sharey=False,label="petal",color='b')
ax[0].set(title='Sepal comparasion ', ylabel='sepal-width')
ax[1].set(title='Petal Comparasion',  ylabel='petal-width')
ax[0].legend()
ax[1].legend()



plt.figure()
fig,ax=plt.subplots(1,2,figsize=(21, 10))

setosa.plot(x='sepal_length', y='sepal_width', kind="scatter",ax=ax[0],sharex=False,sharey=False,label="setosa",color='r')
versicolor.plot(x='sepal_length',y='sepal_width',kind="scatter",ax=ax[0],label='versicolor',color='b')
virginica.plot(x='sepal_length', y='sepal_width', kind="scatter", ax=ax[0], label='virginica', color='g')

setosa.plot(x='petal_length', y='petal_width', kind="scatter",ax=ax[1],label='setosa',color='r')
versicolor.plot(x='petal_length',y='petal_width',kind="scatter",ax=ax[1],label='versicolor',color='b')
virginica.plot(x='petal_length', y='petal_width', kind="scatter", ax=ax[1], label='virginica', color='g')

ax[0].set(title='Sepal comparasion ', ylabel='sepal-width')
ax[1].set(title='Petal Comparasion',  ylabel='petal-width')
ax[0].legend()
ax[1].legend()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# ...

# %% [markdown]
# Ans3.Uploading CSV file from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/My Drive/iris.csv"
df3 = pd.read_csv(path)

# %%
df3.head
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)
print("The maximum values of each column are following:")
maximum=df3.max()
print(maximum)
print("The minimum values of each column are following:")
minimum=df3.min()
print(minimum)
print("The standard deviation values of each column are following:")
std1=df3.std()
print(std1)
# Out:
# The maximum values of each column are following:
# sepal.length          7.9
# sepal.width           4.4
# petal.length          6.9
# petal.width           2.5
# variety         Virginica
# dtype: object
# The minimum values of each column are following:
# sepal.length       4.3
# sepal.width          2
# petal.length         1
# petal.width        0.1
# variety         Setosa
# dtype: object
# The standard deviation values of each column are following:
# sepal.length    0.83
# sepal.width     0.44
# petal.length    1.77
# petal.width     0.76
# dtype: float64
